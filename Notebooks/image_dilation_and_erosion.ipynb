# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# %matplotlib inline
from ipywidgets import interact, widgets
from IPython.display import display
import matplotlib.pyplot as plt
import warnings

from skimage.morphology import disk
from skimage.filters import rank
from skimage.color import rgb2gray
import skimage.data

# %%
import matplotlib.pyplot as plt    
import matplotlib.image as mpimg   #to get image
import numpy as np
import cv2

# %%
def f(k_dil, itr_dil, k_ero, itr_ero):
    kernel_dil = np.ones((k_dil,k_dil), np.uint8)
    kernel_ero = np.ones((k_ero,k_ero), np.uint8)
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        img_erode = cv2.erode(img_gray, kernel_ero, iterations=itr_ero)
        img_dilate = cv2.dilate(img_erode, kernel_dil, iterations=itr_dil)
        

    ax_neu.imshow(img_dilate, cmap="gray")
    fig.canvas.draw()
    display(fig)
image = cv2.imread('/content/drive/MyDrive/IIIT Hyderabad/DIP Assignment/Project/Final_images/final_image_0.png')
img_gray = rgb2gray(image)

fig = plt.figure(figsize=(10, 10))
ax_orig = fig.add_subplot(121) 
ax_neu = fig.add_subplot(122) 

ax_orig.imshow(img_gray, cmap="gray")
ax_neu.imshow(img_gray, cmap="gray")
interact(f, k_dil=widgets.IntSlider(min=1,max=11,step=1,value=1), itr_dil=widgets.IntSlider(min=1,max=10,step=1,value=1),
         k_ero=widgets.IntSlider(min=1,max=11,step=1,value=1), itr_ero=widgets.IntSlider(min=1,max=10,step=1,value=1));
# Out:
# interactive(children=(IntSlider(value=1, description='k_dil', max=11, min=1), IntSlider(value=1, description='…

# %%
image = cv2.imread('/content/drive/MyDrive/IIIT Hyderabad/DIP Assignment/Project/Final_images/final_image_0.png',0)
kernel_dil = np.ones((6,6), np.uint8)
kernel_ero = np.ones((2,2), np.uint8)
img_erode = cv2.erode(image, kernel_ero, iterations=1)
img_dilate = cv2.dilate(img_erode, kernel_dil, iterations=1)
plt.imshow(img_dilate, cmap='gray')
