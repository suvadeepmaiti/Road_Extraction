# %%
import matplotlib.pyplot as plt    
import matplotlib.image as mpimg   #to get image
import numpy as np
import cv2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/IIIT Hyderabad/DIP Assignment/Project
# Out:
# /content/drive/MyDrive/IIIT Hyderabad/DIP Assignment/Project

# %%
def reference_image(img):
  im1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  im1[im1<250]=0
  plt.imshow(im1, cmap='gray')
  return im1

# %%
# %cd/content/drive/MyDrive/IIIT Hyderabad/DIP Assignment/Project/DIP Photos/7. Reference Images
# Out:
# /content/drive/MyDrive/IIIT Hyderabad/DIP Assignment/Project/DIP Photos/7. Reference Images

# %% [markdown]
# **Reference Image 1**

# %%
im_1 = cv2.imread('/content/drive/MyDrive/IIIT Hyderabad/DIP Assignment/Project/DIP Photos/6. Photoshopped/im_1.jpg')
p1 = reference_image(im_1)
cv2.imwrite('Reference_1.png',p1)
# Out:
# True

# %% [markdown]
# **Reference Image 2**

# %%
im_2 = cv2.imread('/content/drive/MyDrive/IIIT Hyderabad/DIP Assignment/Project/DIP Photos/6. Photoshopped/im_2.jpg')
p2 = reference_image(im_2)
cv2.imwrite('Reference_2.png',p2)
# Out:
# True

# %% [markdown]
# **Reference Image 3**

# %%
im_3 = cv2.imread('/content/drive/MyDrive/IIIT Hyderabad/DIP Assignment/Project/DIP Photos/6. Photoshopped/im_3.jpg')
p3 = reference_image(im_3)
cv2.imwrite('Reference_3.png',p3)
# Out:
# True

# %% [markdown]
# **Reference Image 4**

# %%
im_4 = cv2.imread('/content/drive/MyDrive/IIIT Hyderabad/DIP Assignment/Project/DIP Photos/6. Photoshopped/im_4.1.jpg')
p4 = reference_image(im_4)
cv2.imwrite('Reference_4.png',p4)
# Out:
# True

# %% [markdown]
# **Reference Image 5**

# %%
im_5 = cv2.imread('/content/drive/MyDrive/IIIT Hyderabad/DIP Assignment/Project/DIP Photos/6. Photoshopped/im_5.jpg')
p5 = reference_image(im_5)
cv2.imwrite('Reference_5.png',p5)
# Out:
# True

# %% [markdown]
# **Reference Image 6**

# %%
im_6 = cv2.imread('/content/drive/MyDrive/IIIT Hyderabad/DIP Assignment/Project/DIP Photos/6. Photoshopped/im_6.jpg')
p6 = reference_image(im_6)
cv2.imwrite('Reference_6.png',p6)
# Out:
# True

# %% [markdown]
# **Reference Image 7**

# %%
im_7 = cv2.imread('/content/drive/MyDrive/IIIT Hyderabad/DIP Assignment/Project/DIP Photos/6. Photoshopped/im7.jpg')
p7 = reference_image(im_7)
cv2.imwrite('Reference_7.png',p7)
# Out:
# True
