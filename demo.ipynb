# %%
import matplotlib.pyplot as plt
from src import *

# %%
file_name = './images/im4.jpg'
im = cv2.imread(file_name)
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
plt.imshow(im)
plt.show()

# %%
clustered_image = run_roadId(file_name, fg=[])
plt.imshow(clustered_image)
plt.show()

# %%
identified_roads = longest_component_identification(clustered_image)
plt.imshow(identified_roads, cmap='gray')
plt.show()

# %%
filtered_roads = morphological_operations(identified_roads)
plt.imshow(filtered_roads, cmap='gray')
plt.show()

# %%
final_image = np.array(remove_nonroad_areas(filtered_roads,2))
plt.imshow(final_image, cmap='gray')
plt.show()

# %%
ref_img = cv2.imread('./images/ref_im4.png',0)
plt.imshow(ref_img, cmap='gray')
plt.show()

# %%
conclusion_table([final_image], [ref_img])
# Out:
# 48705 17872 8314
# +-------+--------------+-------------+---------+
# | Image | Completeness | Correctness | Quality |
# +-------+--------------+-------------+---------+
# |   1   |   0.73156    |   0.85419   | 0.65035 |
# +-------+--------------+-------------+---------+
